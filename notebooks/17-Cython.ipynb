# %% [markdown]
# # Introduction to Cython
#
# ![Cython Logo](images/440px-Cython-logo.svg.png)
#
# ---
# ## **What is Cython?**
#
# Cython is a **superset of Python** that allows you to:
# - **Write Python-like code** with **static type declarations** (unlike Python’s dynamic typing).
# - **Translate Python code into optimized C/C++** and compile it as a **Python extension module**.
# - **Write fast C code** in a Python-like syntax.
# - **Simplify linking to existing C libraries**.
#
# **Key Benefits:**
# - **Performance**: Cython can significantly speed up Python code, especially for numerical computations.
# - **Compatibility**: Works seamlessly with Python and NumPy.
# - **Ease of Use**: No need to write C code directly; Cython handles the translation.
#
# ---
# ## **Setup for Cython**
#
# To use Cython in Jupyter Notebook, set up the environment as follows:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10, 6)
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---
# ## **Example: Numerical Integration in Python**
#
# Consider the function:
# $$
# f(x) = -4x^3 + 3x^2 + 2x
# $$
#
# **Plot the Function:**

# %%
def f(x):
    return -4 * x**3 + 3 * x**2 + 2 * x

x = np.linspace(-1, 1, 100)
ax = plt.subplot(1, 1, 1)
ax.plot(x, f(x))
ax.fill_between(x, 0, f(x))
plt.title("Plot of $f(x) = -4x^3 + 3x^2 + 2x$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:** A plot of the function $f(x)$ with the area under the curve filled.
#
# ---
# ## **Numerical Integration in Pure Python**
#
# To compute the integral $\int_a^b f(x) \, dx$ numerically using $N$ points:
#
# **Example: Trapezoidal Rule Implementation**

# %%
def integrate_f_py(a, b, N):
    s = 0
    dx = (b - a) / (N - 1)
    for i in range(N - 1):  # Intentionally using a loop for demonstration
        x = a + i * dx
        s += (f(x) + f(x + dx)) / 2
    return s * dx

# Test the function
a, b, N = -1, 1, 1000
result = integrate_f_py(a, b, N)
print(f"Integral from {a} to {b}: {result}")

# %% [markdown]
# **Performance:**

# %%
# %timeit integrate_f_py(-1, 1, 10000)

# %% [markdown]
# **Output:** ~10 ms per loop (slow due to Python loops)
#
# ---
# ## **Optimizing with Cython**
#
# To speed up the integration, rewrite the function in **Cython** with static typing.
#
# ### **Step 1: Write the Cython Code**
#
# Create a file named `integrate_f.pyx`:

# %%
# %%cython
# # integrate_f.pyx
# import numpy as np
# cimport numpy as np
# cimport cython
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# def integrate_f_cy(double a, double b, int N):
#     cdef:
#         double s = 0.0
#         double dx = (b - a) / (N - 1)
#         double x
#         int i
#
#     for i in range(N - 1):
#         x = a + i * dx
#         s += (f(x) + f(x + dx)) / 2
#     return s * dx
#
# def f(double x):
#     return -4 * x**3 + 3 * x**2 + 2 * x

# %% [markdown]
# ---
# ### **Step 2: Compile the Cython Code**
#
# Create a `setup.py` file to compile the Cython code:

# %%
# setup.py
from setuptools import setup
from Cython.Build import cythonize
import numpy

setup(
    name="Integrate with Cython",
    ext_modules=cythonize("integrate_f.pyx"),
    include_dirs=[numpy.get_include()]
)

# %% [markdown]
# **Compile the Extension:**

# %%
# %%bash
# python setup.py build_ext --inplace

# %% [markdown]
# ---
# ### **Step 3: Use the Compiled Cython Function**

# %%
from integrate_f import integrate_f_cy

# Test the Cython function
result = integrate_f_cy(a, b, N)
print(f"Integral from {a} to {b}: {result}")

# Benchmark
# %timeit integrate_f_cy(-1, 1, 10000)

# %% [markdown]
# **Output:** ~100 µs per loop (much faster than pure Python)
#
# ---
# ## **Parallel Computing with Cython and OpenMP**
#
# Cython supports **parallel computing** using OpenMP, which can further speed up computations.
#
# ### **Example: Prime Number Calculation with OpenMP**
#
# **Step 1: Write the Cython Code with OpenMP**
#
# Create a file named `cython_omp.pyx`:

# %%
# %%cython
# # cython_omp.pyx
# import numpy as np
# cimport numpy as np
# cimport cython
# from cython.parallel import prange
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# def prime_array_omp(np.ndarray[np.int32_t, ndim=1] arr):
#     cdef:
#         int i, j
#         int n = arr.shape[0]
#
#     for i in prange(n, nogil=True):
#         if arr[i] < 2:
#             arr[i] = 0
#         else:
#             for j in range(2, int(np.sqrt(arr[i])) + 1):
#                 if arr[i] % j == 0:
#                     arr[i] = 0
#                     break
#     return arr

# %% [markdown]
# ---
# ### **Step 2: Compile with OpenMP Support**
#
# Create a `setup.py` file:

# %%
# setup.py
from setuptools import setup, Extension
from Cython.Build import cythonize
import os, sys
import numpy

if sys.platform == "darwin":  # For macOS, use gcc installed with Homebrew
    os.environ["CC"] = "gcc-10"
    os.environ["CXX"] = "g++-10"

ext_modules = [
    Extension(
        "cython_omp",
        ["cython_omp.pyx"],
        extra_compile_args=['-fopenmp'],
        extra_link_args=['-fopenmp'],
        include_dirs=[numpy.get_include()]
    )
]

setup(
    name='Cython OpenMP Example',
    ext_modules=cythonize(ext_modules),
)

# %% [markdown]
# **Compile the Extension:**

# %%
# %%bash
# python setup.py build_ext --inplace --quiet

# %% [markdown]
# ---
# ### **Step 3: Use the Compiled Cython Function with OpenMP**

# %%
from cython_omp import prime_array_omp

# Test the function
arr = np.arange(20, dtype=np.int32)
result = prime_array_omp(arr)
print(result)  # Output: Array with primes marked as non-zero

# Benchmark
L = np.arange(10**6, dtype=np.int32)
# %timeit prime_array_omp(L)

# %% [markdown]
# **Output:** Faster execution due to parallel processing.
#
# ---
# ## **References**
#
# For further learning, check out these resources:
# - **[Cython Documentation](http://docs.cython.org/en/latest/)**: Official Cython documentation.
# - **[An Interactive Introduction to Cython by Chris Swierczewski](http://www.cswiercz.info/)**: Interactive tutorial.
# - **[Introduction to Python by Michael Kraus](http://michael-kraus.org/introduction-to-python.html)**: General Python introduction.
# - **[Cython by Xavier Juvigny 🇫🇷](http://calcul.math.cnrs.fr/IMG/pdf/cythontalk.pdf)**: Cython talk (in French).
# - **[Cython Wiki](https://github.com/cython/cython/wiki)**: Community-driven resources.
# - **Kurt W. Smith**:
#   - [Cython: A Guide for Python Programmers](http://shop.oreilly.com/product/0636920033431.do)
#   - [Cython: Blend the Best of Python and C++ | SciPy 2015 Tutorial](https://youtu.be/gMvkiQ-gOW8)
#   - [Cython: Speed up Python and NumPy, Pythonize C, C++, and Fortran, SciPy 2013](https://youtu.be/JKCjsRDffXo)
#   - [SciPy 2017 - Cython](https://youtu.be/FepqwPI6U80)
#   - [Cython Book Examples](https://github.com/cythonbook)
# - **[Parallel Computing in Cython/Threads by Neal Hughes](http://nealhughes.net/parallelcomp2/)**: Guide on parallel computing with Cython.
#
# ---
