# %% [markdown]
# # Introduction to SciPy
#
# ![SciPy Logo](images/scipyshiny_small.png)
#
# ---
#
# ## **Overview of SciPy**
#
# [SciPy](https://scipy.org/) is a **scientific computing ecosystem** for Python. It builds on NumPy and provides a **wide range of scientific tools**, including:
# - **Fast Fourier Transforms (FFT)**
# - **Linear algebra** routines
# - **Optimization** algorithms
# - **Integration** and ordinary differential equation (ODE) solvers
# - **Interpolation** and smoothing splines
# - **Signal and image processing**
# - **Sparse matrices** and associated routines
#
# **Key Points:**
# - SciPy **includes NumPy** and can be considered an **extension** of NumPy.
# - The **[Scikits](https://scikits.appspot.com/scikits)** add-on toolkits complement SciPy with additional functionality.
#
# ---
#
# ## **SciPy Main Packages**
#
# SciPy is organized into **sub-packages** that cover various scientific computing domains:
#
# | **Package**       | **Description**                                      |
# |-------------------|------------------------------------------------------|
# | `scipy.constants` | Physical and mathematical constants.                 |
# | `scipy.fftpack`   | Fast Fourier Transform (FFT) routines.              |
# | `scipy.integrate` | Integration and ODE solvers.                         |
# | `scipy.interpolate` | Interpolation and smoothing splines.              |
# | `scipy.io`        | Input and Output (I/O) operations.                   |
# | `scipy.linalg`    | Linear algebra routines.                            |
# | `scipy.signal`    | Signal processing tools.                            |
# | `scipy.sparse`    | Sparse matrices and associated routines.            |
#
# ---
#
# ## **Interpolation with SciPy**
#
# SciPy provides **powerful interpolation** tools in the `scipy.interpolate` module. Interpolation is useful for estimating values between known data points.
#
# **Example: 1D Interpolation**

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10, 6)

from scipy.interpolate import interp1d

# Define sample points
x = np.linspace(-1, 1, num=5)  # 5 points evenly spaced in [-1, 1]
y = (x - 1.) * (x - 0.5) * (x + 0.5)  # Sample values

# Create interpolation functions
f0 = interp1d(x, y, kind='zero')      # Zero-order (constant) interpolation
f1 = interp1d(x, y, kind='linear')    # Linear interpolation
f2 = interp1d(x, y, kind='quadratic') # Quadratic interpolation
f3 = interp1d(x, y, kind='cubic')     # Cubic interpolation
f4 = interp1d(x, y, kind='nearest')   # Nearest-neighbor interpolation

# Define new points for interpolation
xnew = np.linspace(-1, 1, num=40)
ynew = (xnew - 1.) * (xnew - 0.5) * (xnew + 0.5)

# Plot the results
plt.plot(x, y, 'D', label='Original Data')
plt.plot(xnew, f0(xnew), ':', label='Zero-order')
plt.plot(xnew, f1(xnew), '-.', label='Linear')
plt.plot(xnew, f2(xnew), '-', label='Quadratic')
plt.plot(xnew, f3(xnew), '--', label='Cubic')
plt.plot(xnew, f4(xnew), '--', label='Nearest')
plt.plot(xnew, ynew, 'k--', label='True Function')
plt.legend()
plt.title("1D Interpolation Methods")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:** A plot comparing different interpolation methods.
#
# ---
# ## **Solving Linear Systems with SciPy**
#
# SciPy provides tools for solving **linear systems** efficiently, including support for **sparse matrices**.
#
# ---
# ### **Dense Matrix Example**
#
# **Example: Solving a Heat Equation with Dense Matrices**

# %%
# Boundary conditions
Tnorth, Tsouth, Twest, Teast = 100, 20, 50, 50

# Set meshgrid
n = 50
l = 1.0
h = l / (n - 1)
X, Y = np.meshgrid(np.linspace(0, l, n), np.linspace(0, l, n))
T = np.zeros((n, n), dtype='d')

# Set boundary conditions
T[n-1:, :] = Tnorth / h**2
T[:1, :] = Tsouth / h**2
T[:, n-1:] = Teast / h**2
T[:, :1] = Twest / h**2

# Construct the coefficient matrix A
A = np.zeros((n * n, n * n), dtype='d')
nn = n * n
ii = 0
for j in range(n):
    for i in range(n):
        if j > 0:
            jj = ii - n
            A[ii, jj] = -1
        if j < n - 1:
            jj = ii + n
            A[ii, jj] = -1
        if i > 0:
            jj = ii - 1
            A[ii, jj] = -1
        if i < n - 1:
            jj = ii + 1
            A[ii, jj] = -1
        A[ii, ii] = 4
        ii += 1

# Solve the linear system
# %%time
U = np.linalg.solve(A, np.ravel(h**2 * T))

# Reshape the solution
T = U.reshape(n, n)

# Plot the result
plt.contourf(X, Y, T)
plt.colorbar()
plt.title("Temperature Distribution (Dense Matrix)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# **Output:** A contour plot of the temperature distribution.
#
# ---
# ### **Sparse Matrix Example**
#
# For **large systems**, using **sparse matrices** can save memory and computation time.
#
# **Example: Solving the Heat Equation with Sparse Matrices**

# %%
import scipy.sparse as spsp
import scipy.sparse.linalg as spspl

# Boundary conditions
Tnorth, Tsouth, Twest, Teast = 100, 20, 50, 50

# Set meshgrid
n = 50
l = 1.0
h = l / (n - 1)
X, Y = np.meshgrid(np.linspace(0, l, n), np.linspace(0, l, n))
T = np.zeros((n, n), dtype='d')

# Set boundary conditions
T[n-1:, :] = Tnorth / h**2
T[:1, :] = Tsouth / h**2
T[:, n-1:] = Teast / h**2
T[:, :1] = Twest / h**2

# Construct the sparse matrix
bdiag = -4 * np.eye(n)
bup = np.diag([1] * (n - 1), 1)
blow = np.diag([1] * (n - 1), -1)
block = bdiag + bup + blow

# Create a list of n blocks
blist = [block] * n
S = spsp.block_diag(blist)

# Upper and lower diagonal arrays
upper = np.diag(np.ones(n * (n - 1)), n)
lower = np.diag(np.ones(n * (n - 1)), -n)
S += upper + lower

# Solve the sparse linear system
# %%time
U = spspl.solve(S, np.ravel(h**2 * T))

# Plot the result
plt.contourf(X, Y, U.reshape(n, n))
plt.colorbar()
plt.title("Temperature Distribution (Sparse Matrix)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# **Output:** A contour plot of the temperature distribution using sparse matrices.
#
# ---
# ## **Performance Comparison: Dense vs. Sparse Matrices**
#
# - **Dense matrices** are straightforward but **memory-intensive** for large systems.
# - **Sparse matrices** are **memory-efficient** and faster for large, sparse systems.
#
# **Key Takeaway:** Use sparse matrices when dealing with **large systems** where most elements are zero.
#
# ---
