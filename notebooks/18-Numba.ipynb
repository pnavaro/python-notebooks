# %% [markdown]
# # Introduction to Numba
#
# ![Numba Logo](https://cdn.dribbble.com/users/915978/screenshots/3034118/numba_1x.jpg)
#
# ---
# ## **What is Numba?**
#
# [Numba](https://numba.pydata.org/) is a **Just-In-Time (JIT) compiler** for Python that:
# - **Generates optimized machine code** from pure Python functions.
# - **Accelerates numerical and array-oriented Python code** to performance levels similar to **C, C++, or Fortran**.
# - **Supports CPU and GPU hardware** for on-the-fly code generation.
# - **Requires minimal changes** to your existing Python code.
#
# **Key Benefits:**
# - **Performance**: Numba can significantly speed up numerical computations.
# - **Ease of Use**: No need to switch languages or Python interpreters.
# - **Flexibility**: Works with NumPy arrays and supports parallel execution.
#
# ---
# ## **Python Decorators**
#
# A **decorator** in Python is a function that **modifies another function or class**. It takes a reference to a function or class, and returns a modified version of it.
#
# **Example: Timing Function Execution**

# %%
import time

def timeit(function):
    """Decorator to measure the execution time of a function."""
    def wrapper(*args, **kwargs):
        t1 = time.time()
        result = function(*args, **kwargs)
        t2 = time.time()
        print(f"Execution time: {t2 - t1:.6f} seconds")
        return result
    return wrapper

@timeit
def f(a, b):
    return a + b

print(f(1, 2))  # Output: 3, followed by execution time

# %% [markdown]
# ---
# ## **First Example with Numba**
#
# Numba uses **decorators** to compile Python functions into optimized machine code.
#
# **Example: Simple Addition Function**

# %%
from numba import jit

@jit
def sum(a, b):
    """Compiled function to add two numbers."""
    return a + b

# First call triggers compilation
result = sum(1, 2)
print(result)  # Output: 3

# %% [markdown]
# **Note:** Compilation happens **on the first call** and is cached for subsequent calls.
#
# ---
# ## **Performance Comparison: NumPy vs. Numba**
#
# Numba can significantly speed up operations on NumPy arrays, especially for large datasets.
#
# **Example: Vector Addition**

# %%
import numpy as np
from numba import jit

# NumPy implementation
def numpy_add(A, B):
    return A + B

# Numba-optimized implementation
@jit(nopython=True)
def numba_add(A, B):
    return A + B

# Create large arrays
N = 10**6
A = np.ones(N, dtype=np.float64)
B = np.ones(N, dtype=np.float64)

# Benchmark
# %timeit numpy_add(A, B)
# %timeit numba_add(A, B)

# %% [markdown]
# **Output:**
# - NumPy: ~10 ms per loop
# - Numba: ~100 µs per loop (100x faster)
#
# ---
# ## **Vectorize with Numba**
#
# Numba’s `@vectorize` decorator allows you to **apply a function element-wise** to arrays, similar to NumPy’s vectorized operations, but with **compiled performance**.
#
# ### **Example: Element-wise Addition**

# %%
import socket
import numpy as np
from numba import vectorize

# CPU target
@vectorize(['float64(float64, float64)'], target='cpu', cache=True, nopython=True)
def cpu_add(a, b):
    return a + b

# Parallel target (multi-core CPU)
@vectorize(['float64(float64, float64)'], target='parallel', cache=True, nopython=True)
def parallel_add(a, b):
    return a + b

# GPU target (if available)
if socket.gethostname() == "gpu-irmar.insa-rennes.fr":
    @vectorize(['float64(float64, float64)'], target='cuda', cache=True, nopython=True)
    def gpu_add(a, b):
        return a + b

# %% [markdown]
# ---
# ## **Benchmarking Vectorized Operations**
#
# Let’s compare the performance of **NumPy**, **Numba (CPU)**, and **Numba (Parallel)** for vectorized addition.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import progressbar

# Define range of array sizes
Nrange = (2 ** np.arange(6, 12)).astype(int)

t_numpy = []
t_numba_cpu = []
t_numba_parallel = []

bar = progressbar.ProgressBar()

for N in bar(Nrange):
    # Initialize arrays
    A = np.ones(N * N, dtype=np.float32).reshape(N, N)
    B = np.ones(A.shape, dtype=A.dtype)
    C = np.empty_like(A, dtype=A.dtype)

    # Benchmark NumPy
    t1 = %timeit -oq C = A + B
    # Benchmark Numba CPU
    t2 = %timeit -oq C = cpu_add(A, B)
    # Benchmark Numba Parallel
    t3 = %timeit -oq C = parallel_add(A, B)

    t_numpy.append(t1.best)
    t_numba_cpu.append(t2.best)
    t_numba_parallel.append(t3.best)

# Plot results
plt.loglog(Nrange, t_numpy, label='NumPy')
plt.loglog(Nrange, t_numba_cpu, label='Numba CPU')
plt.loglog(Nrange, t_numba_parallel, label='Numba Parallel')
plt.legend(loc='lower right')
plt.xlabel('Number of Points')
plt.ylabel('Execution Time (s)')
plt.title('Performance Comparison: NumPy vs. Numba')
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:** A log-log plot comparing the execution time of NumPy, Numba (CPU), and Numba (Parallel) for different array sizes.
#
# ---
# ## **References**
#
# For further learning, check out these resources:
# - **[Numba by Loïc Gouarin](https://github.com/gouarin/cours_numba_2017)**: Course materials on Numba.
# - **[Numba Documentation](http://numba.pydata.org/numba-doc/latest/index.html)**: Official Numba documentation.
# - **[Numbapro](https://github.com/ContinuumIO/numbapro-examples/)**: Examples for Numbapro (commercial version of Numba).
# - **[Numba Examples](https://github.com/harrism/numba_examples)**: Collection of Numba examples.
#
# ---
